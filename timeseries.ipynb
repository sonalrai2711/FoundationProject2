# %%
#!pip install mlflow --quiet
#!pip install pyngrok --quiet

# %%
#!pip install Jinja2
#!pip install markupsafe==2.0.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached MarkupSafe-2.0.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (31 kB)
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 2.1.1
#     Uninstalling MarkupSafe-2.1.1:
#       Successfully uninstalled MarkupSafe-2.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires markupsafe~=2.1.1, but you have markupsafe 2.0.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
import mlflow
tracking_uri = mlflow.get_tracking_uri()
print("Current tracking uri: {}".format(tracking_uri))
# Out:
# Current tracking uri: file:///C:/Users/deepi/Downloads/Python%20codes/fp2_assignment/mlruns

# %%
import pandas as pd
import jinja2

# %%
sdge_final_data = pd.read_csv('merged_sdge_data.csv')
sdge_final_data
# Out:
#             Date          SDGE  Year  Month  Day   Week_day  Season  Holiday  \
# 0     2019-01-01  48485.355385  2019      1    1    Tuesday  winter        1
# 1     2019-01-02  56532.901573  2019      1    2  Wednesday  winter        0
# 2     2019-01-03  57024.675624  2019      1    3   Thursday  winter        0
# 3     2019-01-04  56456.888148  2019      1    4     Friday  winter        0
# 4     2019-01-05  55838.513720  2019      1    5   Saturday  winter        0
# ...          ...           ...   ...    ...  ...        ...     ...      ...
# 1211  2022-04-26  46399.542960  2022      4   26    Tuesday  winter        0
# 1212  2022-04-27  44594.505611  2022      4   27  Wednesday  winter        0
# 1213  2022-04-28  46513.391923  2022      4   28   Thursday  winter        0
# 1214  2022-04-29  43917.675495  2022      4   29     Friday  winter        0
# 1215  2022-04-30  41303.160069  2022      4   30   Saturday  winter        0
#
# ...

# %%
#!pip install -U git+https://github.com/pycaret/pycaret.git@develop --quiet
#!pip install pycaret.utils
#!pip install pycaret-ts-alpha --quiet
#from pycaret.time_series import *

# %%
def what_is_installed():
    from pycaret import show_versions
    show_versions()

try:
    what_is_installed()
except ModuleNotFoundError:
    # !pip install pycaret-ts-alpha
    what_is_installed()
# Out:
# System:
#     python: 3.7.13 (default, Apr 24 2022, 01:04:09)  [GCC 7.5.0]
# executable: /usr/bin/python3
#    machine: Linux-5.4.188+-x86_64-with-Ubuntu-18.04-bionic
#
# Python dependencies:
#           pip: 21.1.3
#    setuptools: 57.4.0
#       pycaret: 3.0.0
#       sklearn: 1.0.2
#        sktime: 0.10.1
#   statsmodels: 0.13.2
#         numpy: 1.21.6
#         scipy: 1.7.3
#        pandas: 1.3.5
#    matplotlib: 3.2.2
#        plotly: 5.9.0
#        joblib: 1.0.1
#         numba: 0.55.2
#        mlflow: Not installed
#      lightgbm: 3.3.2
#       xgboost: 0.90
#      pmdarima: 1.8.5
#         tbats: Installed but version unavailable
#       prophet: Not installed
#       tsfresh: Not installed

# %%
import time
import numpy as np
from pycaret.time_series import TSForecastingExperiment
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [7], in <cell line: 3>()
#       1 import time
#       2 import numpy as np
# ----> 3 from pycaret.time_series import TSForecastingExperiment
#
# File ~\anaconda3\envs\pytimeenv\lib\site-packages\pycaret\time_series\__init__.py:1, in <module>
# ----> 1 from pycaret.time_series.forecasting.oop import TSForecastingExperiment
#       2 from pycaret.time_series.forecasting.functional import (
#       3     setup,
#       4     create_model,
#    (...)
#      25     check_stats,
#      26 )
#      28 __all__ = [
#      29     "TSForecastingExperiment",
#      30     "setup",
#    (...)
#      52     "check_stats",
#      53 ]
#
# File ~\anaconda3\envs\pytimeenv\lib\site-packages\pycaret\time_series\forecasting\oop.py:16, in <module>
#      14 from sklearn.base import clone
# ...

# %%
# We want to forecast the next 12 months of data and we will use 3 fold cross-validation to test the models.
fh = 30
fold = 3

# %%
# Global Plot Settings
fig_kwargs={'renderer': 'notebook'}

# %%
sdge_final_data["consumption_date"] = pd.to_datetime(sdge_final_data["Date"]+" "+"00:00:00")
sdge_final_data.drop(columns=["Date"], inplace=True)
target = "SDGE"
sdge_final_data_new = pd.get_dummies(sdge_final_data, columns = ['Week_day', 'Season', 'Non_working'])
sdge_final_data_new
# Out:
#              SDGE  Year  Month  Day  Holiday  DailyCoolingDegreeDays  \
# 0     48485.35539  2019      1    1        1                     0.0
# 1     56532.90157  2019      1    2        0                     0.0
# 2     57024.67562  2019      1    3        0                     0.0
# 3     56456.88815  2019      1    4        0                     0.0
# 4     55838.51372  2019      1    5        0                     0.0
# ...           ...   ...    ...  ...      ...                     ...
# 1211  46399.54296  2022      4   26        0                     0.0
# 1212  44594.50561  2022      4   27        0                     0.0
# 1213  46513.39192  2022      4   28        0                     0.0
# 1214  43917.67549  2022      4   29        0                     0.0
# 1215  41303.16007  2022      4   30        0                     0.0
#
#       DailyHeatingDegreeDays  HourlyDryBulbTemperature consumption_date  \
# ...

# %%
eda = TSForecastingExperiment()
eda.setup(
    data=sdge_final_data_new, target=target, index="consumption_date", fh=fh, 
    fig_kwargs={"renderer": "notebook", "width": 1000, "height": 600},
    session_id=42, log_experiment = True, experiment_name = 'consumption'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 eda = TSForecastingExperiment()
#       2 eda.setup(
#       3     data=sdge_final_data_new, target=target, index="consumption_date", fh=fh,
#       4     fig_kwargs={"renderer": "notebook", "width": 1000, "height": 600},
#       5     session_id=42, log_experiment = True, experiment_name = 'consumption'
#       6 )
#
# NameError: name 'TSForecastingExperiment' is not defined

# %%
plot_model(plot="ts")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# ACF and PACF for the original dataset
plot_model(plot="acf")

# NOTE: you can customize the plots with kwargs - e.g. number of lags, figure size (width, height), etc
# data_kwargs such as `nlags` are passed to the underlying function that gets the ACF values
# figure kwargs such as `fig_size` & `template` are passed to plotly and can have any value that plotly accepts
plot_model(
    plot="pacf",
    data_kwargs={'nlags':36},
    fig_kwargs={'fig_size': [800, 500], 'template': 'simple_white'}
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(plot="diagnostics", fig_kwargs={"height": 800, "width": 1000})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(
    plot="diff",
    data_kwargs={
        "lags_list": [[1], [1, 12]],
        "acf": True, "pacf": True, "periodogram": True
    },
    fig_kwargs={"height": 600, "width": 1000}
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# First, classical decomposition
# By default the seasonal period is the one detected during setup - 12 in this case.
plot_model(plot="decomp")

# Users can chnage the seasonal period to explore what is best for this model.
plot_model(plot="decomp", data_kwargs={'seasonal_period': 30})

# Users may wish to customize the decomposition, for example, in this case multiplicative seasonality
# probably makes more sense since the magnitide of the seasonality increase as the time progresses
plot_model(plot="decomp", data_kwargs={'type': 'multiplicative'})

# Users can also plot STL decomposition
# Reference: https://otexts.com/fpp2/stl.html
plot_model(plot="decomp_stl")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Show the train-test splits on the dataset
# Internally split - len(fh) as test set, remaining used as test set
plot_model(plot="train_test_split", fig_kwargs={"height": 400, "width": 900})

# Show the Cross Validation splits inside the train set
# The blue dots represent the training data for each fold.
# The orange dots represent the validation data for each fold
plot_model(plot="cv", fig_kwargs={"height": 400, "width": 900})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
check_stats(test="summary")
# Out:
#       Test   Test Name    Data            Property Setting         Value
# 0  Summary  Statistics  Actual              Length          9.000000e+01
# 1  Summary  Statistics  Actual                Mean          4.960367e+03
# 2  Summary  Statistics  Actual              Median          4.776500e+03
# 3  Summary  Statistics  Actual  Standard Deviation          1.939000e+03
# 4  Summary  Statistics  Actual            Variance          3.759721e+06
# 5  Summary  Statistics  Actual            Kurtosis         -9.201133e-01
# 6  Summary  Statistics  Actual            Skewness          2.262201e-01
# 7  Summary  Statistics  Actual   # Distinct Values          8.900000e+01

# %%
check_stats(test='stationarity')
# Out:
#             Test Test Name    Data             Property          Setting  \
# 0   Stationarity       ADF  Actual         Stationarity  {'alpha': 0.05}
# 1   Stationarity       ADF  Actual              p-value  {'alpha': 0.05}
# 2   Stationarity       ADF  Actual       Test Statistic  {'alpha': 0.05}
# 3   Stationarity       ADF  Actual    Critical Value 1%  {'alpha': 0.05}
# 4   Stationarity       ADF  Actual    Critical Value 5%  {'alpha': 0.05}
# 5   Stationarity       ADF  Actual   Critical Value 10%  {'alpha': 0.05}
# 6   Stationarity      KPSS  Actual   Trend Stationarity  {'alpha': 0.05}
# 7   Stationarity      KPSS  Actual              p-value  {'alpha': 0.05}
# 8   Stationarity      KPSS  Actual       Test Statistic  {'alpha': 0.05}
# 9   Stationarity      KPSS  Actual   Critical Value 10%  {'alpha': 0.05}
# 10  Stationarity      KPSS  Actual    Critical Value 5%  {'alpha': 0.05}
# 11  Stationarity      KPSS  Actual  Critical Value 2.5%  {'alpha': 0.05}
# ...

# %%
# Ljung-Bx test to tests of white noise (whether the data is uncorrelated or not)
check_stats(test='white_noise')
# Out:
#           Test  Test Name    Data        Property                   Setting  \
# 0  White Noise  Ljung-Box  Actual  Test Statictic  {'alpha': 0.05, 'K': 24}
# 1  White Noise  Ljung-Box  Actual  Test Statictic  {'alpha': 0.05, 'K': 48}
# 2  White Noise  Ljung-Box  Actual         p-value  {'alpha': 0.05, 'K': 24}
# 3  White Noise  Ljung-Box  Actual         p-value  {'alpha': 0.05, 'K': 48}
# 4  White Noise  Ljung-Box  Actual     White Noise  {'alpha': 0.05, 'K': 24}
# 5  White Noise  Ljung-Box  Actual     White Noise  {'alpha': 0.05, 'K': 48}
#
#         Value
# 0   293.08932
# 1  460.125833
# 2         0.0
# 3         0.0
# 4       False
# 5       False

# %%
# Users have the option to customize the tests such as change the alpha value.
check_stats(test='kpss', alpha = 0.2)
# Out:
#            Test Test Name    Data             Property         Setting  \
# 0  Stationarity      KPSS  Actual   Trend Stationarity  {'alpha': 0.2}
# 1  Stationarity      KPSS  Actual              p-value  {'alpha': 0.2}
# 2  Stationarity      KPSS  Actual       Test Statistic  {'alpha': 0.2}
# 3  Stationarity      KPSS  Actual   Critical Value 10%  {'alpha': 0.2}
# 4  Stationarity      KPSS  Actual    Critical Value 5%  {'alpha': 0.2}
# 5  Stationarity      KPSS  Actual  Critical Value 2.5%  {'alpha': 0.2}
# 6  Stationarity      KPSS  Actual    Critical Value 1%  {'alpha': 0.2}
#
#       Value
# 0     False
# 1       0.1
# 2  0.032908
# 3     0.119
# 4     0.146
# 5     0.176
# 6     0.216

# %%
check_stats()
# Out:
#             Test   Test Name    Data             Property  \
# 0        Summary  Statistics  Actual               Length
# 1        Summary  Statistics  Actual                 Mean
# 2        Summary  Statistics  Actual               Median
# 3        Summary  Statistics  Actual   Standard Deviation
# 4        Summary  Statistics  Actual             Variance
# 5        Summary  Statistics  Actual             Kurtosis
# 6        Summary  Statistics  Actual             Skewness
# 7        Summary  Statistics  Actual    # Distinct Values
# 8    White Noise   Ljung-Box  Actual       Test Statictic
# 9    White Noise   Ljung-Box  Actual       Test Statictic
# 10   White Noise   Ljung-Box  Actual              p-value
# 11   White Noise   Ljung-Box  Actual              p-value
# 12   White Noise   Ljung-Box  Actual          White Noise
# 13   White Noise   Ljung-Box  Actual          White Noise
# 14  Stationarity         ADF  Actual         Stationarity
# ...

# %%
eda.models()
# Out:
#                                                               Name  \
# ID
# arima                                                        ARIMA
# auto_arima                                              Auto ARIMA
# lr_cds_dt               Linear w/ Cond. Deseasonalize & Detrending
# en_cds_dt          Elastic Net w/ Cond. Deseasonalize & Detrending
# ridge_cds_dt             Ridge w/ Cond. Deseasonalize & Detrending
# lasso_cds_dt             Lasso w/ Cond. Deseasonalize & Detrending
# lar_cds_dt       Least Angular Regressor w/ Cond. Deseasonalize...
# llar_cds_dt      Lasso Least Angular Regressor w/ Cond. Deseaso...
# br_cds_dt        Bayesian Ridge w/ Cond. Deseasonalize & Detren...
# huber_cds_dt             Huber w/ Cond. Deseasonalize & Detrending
# par_cds_dt       Passive Aggressive w/ Cond. Deseasonalize & De...
# omp_cds_dt       Orthogonal Matching Pursuit w/ Cond. Deseasona...
# knn_cds_dt         K Neighbors w/ Cond. Deseasonalize & Detrending
# ...

# %%
sdge_final_data_new.set_index("consumption_date", inplace=True)

# %%
exog_vars = ["SDGE","Year","Month","Day","Holiday","DailyCoolingDegreeDays","DailyHeatingDegreeDays","HourlyDryBulbTemperature","Week_day_Friday","Week_day_Monday","Week_day_Saturday", "Week_day_Sunday", "Week_day_Thursday", "Week_day_Tuesday", "Week_day_Wednesday", "Season_summer","Season_winter", "Non_working_non-working","Non_working_working"]
data = sdge_final_data_new[exog_vars]
data.head()
# Out:
#                          SDGE  Year  Month  Day  Holiday  \
# consumption_date
# 2019-01-01        48485.35539  2019      1    1        1
# 2019-01-02        56532.90157  2019      1    2        0
# 2019-01-03        57024.67562  2019      1    3        0
# 2019-01-04        56456.88815  2019      1    4        0
# 2019-01-05        55838.51372  2019      1    5        0
#
#                   DailyCoolingDegreeDays  DailyHeatingDegreeDays  \
# consumption_date
# 2019-01-01                           0.0                    12.0
# 2019-01-02                           0.0                    13.0
# 2019-01-03                           0.0                    12.0
# 2019-01-04                           0.0                    12.0
# 2019-01-05                           0.0                     9.0
#
#                   HourlyDryBulbTemperature  Week_day_Friday  Week_day_Monday  \
# consumption_date
# 2019-01-01                       52.344828                0                0
# ...

# %%
#### Global Figure Settings for notebook ----
global_fig_settings = {"renderer": "notebook", "width": 1000, "height": 600}

exog_exps = []
exog_models = []
for exog_var in exog_vars:
    exog_exp = TSForecastingExperiment()
    exog_exp.setup(
        data=data[exog_var], fh=48,
        # numeric_imputation_target="ffill",
        fig_kwargs=global_fig_settings, session_id=42
    )

    # Users can customize how to model future exogenous variables i.e. add
    # more steps and models to potentially get better models at the expense
    # of higher modeling time.
    best = exog_exp.compare_models(
        sort="rmse", include=["arima", "ets", "exp_smooth", "theta", "lightgbm_cds_dt",]        
    )
    final_exog_model = exog_exp.finalize_model(best)

    exog_exps.append(exog_exp)
    exog_models.append(final_exog_model)

# Step 2: Get future predictions for exog variables ----
future_exog = [
    exog_exp.predict_model(exog_model)
    for exog_exp, exog_model in zip(exog_exps, exog_models)
]
future_exog = pd.concat(future_exog, axis=1)
future_exog.columns = exog_vars
# Out:
#                                                              Model     MAE  \
# exp_smooth                                   Exponential Smoothing   0.066
# ets                                                            ETS  0.0665
# arima                                                        ARIMA  0.0453
# lightgbm_cds_dt  Light Gradient Boosting w/ Cond. Deseasonalize...  0.1044
# theta                                             Theta Forecaster  0.4387
#
#                    RMSE                   MAPE   SMAPE    MASE   RMSSE  \
# exp_smooth       0.1938  181236498252262.71875  0.6934  0.0102   0.871
# ets               0.196  182358136168736.46875  0.6939  0.0103   0.881
# arima            0.2004  193361389325611.65625  0.6691   0.007  0.9001
# lightgbm_cds_dt  0.2112    245527112348794.125  0.7206  0.0162  0.9492
# theta            0.4718   1027253984368828.875  0.9168  0.0677  2.1166
#
#                      R2  TT (Sec)
# exp_smooth       0.8237    0.2467
# ...

# %%
future_exog
# Out:
#                   SDGE       Year   Month      Day  Holiday  \
# 2022-05-01  41350.4014  2021.9976  4.1167  27.3546   0.0108
# 2022-05-02  48749.2879  2021.9955  4.1498  25.1989   0.1181
# 2022-05-03  46937.0801  2021.9928  4.1910  23.4423   0.0289
# 2022-05-04  44956.7334  2021.9966  4.1843  22.0109   0.0361
# 2022-05-05  46752.1813  2021.9947  4.2122  20.8445   0.0472
# 2022-05-06  44069.5496  2021.9985  4.1816  19.8940   0.0231
# 2022-05-07  41393.8357  2022.0020  4.1615  19.1195   0.0102
# 2022-05-08  41397.9861  2021.9996  4.1888  18.4884   0.0110
# 2022-05-09  48766.5315  2021.9975  4.2219  17.9741   0.1183
# 2022-05-10  46932.9599  2021.9948  4.2551  17.5551   0.0291
# 2022-05-11  44937.5707  2021.9986  4.2188  17.2136   0.0363
# 2022-05-12  46722.4268  2021.9967  4.2405  16.9353   0.0474
# 2022-05-13  44032.3374  2022.0005  4.2099  16.7086   0.0233
# 2022-05-14  41351.3723  2022.0040  4.1679  16.5238   0.0104
# 2022-05-15  41351.8252  2022.0016  4.1952  16.3732   0.0112
# ...

# %%
best = compare_models()
# Out:
#                                                              Model        MAE  \
# auto_arima                                              Auto ARIMA   531.9167
# arima                                                        ARIMA   568.4974
# lightgbm_cds_dt  Light Gradient Boosting w/ Cond. Deseasonalize...   571.1749
# et_cds_dt          Extra Trees w/ Cond. Deseasonalize & Detrending    583.112
# theta                                             Theta Forecaster   543.8821
# gbr_cds_dt       Gradient Boosting w/ Cond. Deseasonalize & Det...   604.1178
# rf_cds_dt        Random Forest w/ Cond. Deseasonalize & Detrending   614.7098
# exp_smooth                                   Exponential Smoothing   542.7593
# lr_cds_dt               Linear w/ Cond. Deseasonalize & Detrending   632.7132
# lar_cds_dt       Least Angular Regressor w/ Cond. Deseasonalize...   632.7132
# en_cds_dt          Elastic Net w/ Cond. Deseasonalize & Detrending   632.7142
# ...

# %%
# finalize the model
final_best = finalize_model(best)# save model to disk
save_model(final_best, 'consumption-pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (AutoARIMA(random_state=123, sp=7, suppress_warnings=True),
#  'consumption-pipeline.pkl')

# %%
save_model(final_best, '/content')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (AutoARIMA(random_state=123, sp=7, suppress_warnings=True), '/content.pkl')

# %%
load_model('/content/consumption-pipeline')
# Out:
# Transformation Pipeline and Model Successfully Loaded
# AutoARIMA(random_state=123, sp=7, suppress_warnings=True)

# %%
import mlflow

# %%
get_ipython().system_raw("mlflow ui --port 5000 &")

# %%
from pyngrok import ngrok

# Terminate open tunnels if exist
ngrok.kill()

# Setting the authtoken (optional)
# Get your authtoken from https://dashboard.ngrok.com/auth
NGROK_AUTH_TOKEN = "2BkYNPeRBMXysXfFYzAPdBuo3Uo_4Mz4msTCn7QLkUnM9dPBW"
ngrok.set_auth_token(NGROK_AUTH_TOKEN)

# Open an HTTPs tunnel on port 5000 for http://localhost:5000
ngrok_tunnel = ngrok.connect(addr="5000", proto="http", bind_tls=True)
print("MLflow Tracking UI:", ngrok_tunnel.public_url)
# Out:
# MLflow Tracking UI: https://b2d6-35-232-82-24.ngrok.io

# %%
# load model
from pycaret.regression import load_model
pipeline = load_model('/content/mlruns/1/dc672edf875f42118e7294249c0d611e/artifacts/model/model')# print pipeline
print(pipeline)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       id_columns=[], ml_usecase='regression',
#                                       numerical_features=[], target='SDGE',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strategy='m...
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                 ['trained_model',
# ...

# %%
exp_future = TSForecastingExperiment()
final_slim_model = exp_future.load_model("consumption_model")
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
from pycaret.regression import predict_model
predictions = predict_model(pipeline, data=sdge_final_data)
predictions.head()
# Out:
#                 Model       MAE           MSE      RMSE      R2   RMSLE  \
# 0  CatBoost Regressor  961.4819  1.945810e+06  1394.923  0.9562  0.0266
#
#      MAPE
# 0  0.0185
#                   Date         SDGE  Year  Month  Day   Week_day  Season  \
# 0  2019-01-01 00:00:00  48485.35539  2019      1    1    Tuesday  winter
# 1  2019-01-02 00:00:00  56532.90157  2019      1    2  Wednesday  winter
# 2  2019-01-03 00:00:00  57024.67562  2019      1    3   Thursday  winter
# 3  2019-01-04 00:00:00  56456.88815  2019      1    4     Friday  winter
# 4  2019-01-05 00:00:00  55838.51372  2019      1    5   Saturday  winter
#
#    Holiday  Non_working  DailyCoolingDegreeDays  DailyHeatingDegreeDays  \
# 0        1  non-working                     0.0                    12.0
# 1        0      working                     0.0                    13.0
# 2        0      working                     0.0                    12.0
# ...
